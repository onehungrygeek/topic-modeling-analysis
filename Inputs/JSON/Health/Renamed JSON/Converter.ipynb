# %%
import pandas as pd

# %%
df = pd.read_json('Health (1).json')

# %%
df
# Out:
#                                               content  \
# 0   The health care system should finance more mon...
# 1     with the exception of the elderly and the youth
# 2   Every health insurance in America should provi...
# 3   medicare/medicaid should be equal people of al...
# 4   Insurance companies should make the co-payment...
# 5   This will help with people actually staying cu...
# 6   Medicare/Medicaid should get a "flex card" wit...
# 7   When prescribed drugs the doctor should have a...
# 8   Physicians should evaluate and give tips to pe...
# 9   People with chronic illnesses should have spec...
# 10  All doctors and physicians should have a small...
# 11  Physicians need to go to seminars and small co...
# 12  Emergency room visits should be less expensive...
# 13  Nursing homes should be covered by Medicare si...
# 14  The government could pull out all money going ...
# 15  People with chronic illnesses should seek the ...
# ...

# %%
lister = df.content.tolist()

# %%
lister[0]
# Out:
# 'The health care system should finance more money the people who are less healthy and ill or have some sort of disease and not as much to the people who are regularly healthy'

# %%
thefile = open("testfile.txt","w")

for item in lister:
    thefile.write("%s\n" % item)

# %%
thefile = open("testfile.txt","r")

# %%
print(thefile.read())
# Out:
# The health care system should finance more money the people who are less healthy and ill or have some sort of disease and not as much to the people who are regularly healthy
# with the exception of the elderly and the youth
# Every health insurance in America should provide 2 to 3 free clinical check ups for a family of 3 or more, and 1 to 2 for single households.
# medicare/medicaid should be equal people of all income but at the same time affordable
# Insurance companies should make the co-payments based upon yearly household income.
# This will help with people actually staying current on their health.
# Medicare/Medicaid should get a "flex card" with so much money on it yearly so that will be able to pay for at least their prescriptions.
# ...
